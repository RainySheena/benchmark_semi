# %% [markdown]
# ### Import the necessary library

# %%
import torch.utils.data
import scanpy as sc
from sklearn.cluster import KMeans
from scipy.spatial import distance
import scipy.sparse
import scib 
import numpy as np
import random
import pandas as pd
from torch.distributions import  kl_divergence as kl
torch.backends.cudnn.benchmark = True
from sklearn.neighbors import KDTree
from sklearn import preprocessing
import scipy
import scib
# import louvain

# %%
import scanpy as sc
import numpy as np
import pandas as pd
import time
import scvi
import anndata
import pandas as pd
from scipy.io import mmread
from scipy.sparse import csr_matrix
import umap
import matplotlib.pyplot as plt
import os
import tempfile
import seaborn as sns
import torch
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import f1_score

import warnings
warnings.filterwarnings("ignore")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/lightning/fabric/__init__.py:40: Deprecated call to `pkg_resources.declare_namespace('lightning.fabric')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# /opt/anaconda3/lib/python3.12/site-packages/pkg_resources/__init__.py:2317: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('lightning')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(parent)
# /opt/anaconda3/lib/python3.12/site-packages/lightning/pytorch/__init__.py:37: Deprecated call to `pkg_resources.declare_namespace('lightning.pytorch')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# /opt/anaconda3/lib/python3.12/site-packages/pkg_resources/__init__.py:2317: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('lightning')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(parent)

# %%
import warnings

sc.set_figure_params(figsize=(6, 6), frameon=False)
sns.set_theme()
torch.set_float32_matmul_precision("high")
save_dir = tempfile.TemporaryDirectory()

# %config InlineBackend.print_figure_kwargs={"facecolor": "w"}
# %config InlineBackend.figure_format="retina"

import warnings
warnings.filterwarnings("ignore")

# Suppress specific ImportWarning
warnings.filterwarnings("ignore", category=ImportWarning, message=".*AltairImportHook.find_spec() not found; falling back to find_module.*")

# %%
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
pandas2ri.activate()

#Perhaps require the library relocation (to the library contains kBET and lisi library)
robjects.r('.libPaths(c("current path", "library location"))')

rscript = '''
library(kBET)
# library(lisi)
'''
robjects.r(rscript)
kbet = robjects.r('kBET')
# lisi = robjects.r['compute_lisi']

# %% [markdown]
# ### read the data

# %%
# load the prediction results to adata
import anndata
adata = anndata.read_h5ad("../Lung_atlas_public.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 32472 × 15148
#     obs: 'dataset', 'location', 'nGene', 'nUMI', 'patientGroup', 'percent.mito', 'protocol', 'sanger_type', 'size_factors', 'sampling_method', 'batch', 'cell_type', 'donor'
#     layers: 'counts'

# %%
# preprocessing
import scanpy as sc
adata.raw = adata
adata.layers["counts"] = adata.X.copy()
sc.pp.filter_cells(adata, min_genes=300)
sc.pp.filter_genes(adata, min_cells=5)
sc.pp.normalize_per_cell(adata, counts_per_cell_after=1e4)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, n_top_genes=2000, batch_key='batch')
adata = adata[:, adata.var['highly_variable']]

# %% [markdown]
# ## Print the normal metrics (for scib)

# %%
import pandas as pd
import scib

def calculate_metrics_for_embeddings(file_path, adata, embedding_keys, batch_key='batch', label_key='cell_type'):
    # Read the CSV file into a DataFrame
    combined_embeddings = pd.read_csv(file_path, index_col=0)

    # Ensure indices match
    combined_embeddings = combined_embeddings.loc[adata.obs_names]

    # Split the DataFrame into separate DataFrames for each embedding
    embeddings_dict = {key: combined_embeddings.filter(like=key) for key in embedding_keys}

    # Assign the embeddings back to adata.obsm
    for key, df in embeddings_dict.items():
        adata.obsm[key] = df.values

    # Initialize an empty list to store results
    results = []

    # Loop through each embedding and calculate metrics
    for key in embedding_keys:
        print(f"File: {file_path}, Embedding: {key}")
        sc.pp.neighbors(adata, use_rep=key)
        scib.me.cluster_optimal_resolution(adata, cluster_key="cluster", label_key=label_key)
        metrics = scib.me.metrics(
            adata, adata_int=adata, 
            silhouette_=True, graph_conn_=True, 
            ari_=True, nmi_=True, isolated_labels_=True, 
            isolated_labels_f1_=True,
            isolated_labels_asw_=True, 
            batch_key=batch_key, label_key=label_key, 
            embed=key
        )
        
        for metric, score in metrics.items():
            # Store results with identifying information
            result_entry = {
                'file_path': file_path,
                'embedding_key': key,
                'metric': metric,
                'score': score
            }
            results.append(result_entry)
            
            # Print the file path, embedding key, and result
            print(f"File: {file_path}, Embedding: {key}, Metric: {metric}, Score: {score}")

    return results

# %%
file_paths = [
    # "../embeddings/full_annotated_supervised_lung_atlas_new.csv",
    "../embeddings/cell_assign_lung_atlas_new.csv",
    # "../embeddings/azimuth_lung_atlas_new.csv",
    "../embeddings/singleR_lung_atlas_new.csv",
    # "../embeddings/partially_annotated_batches_lung_atlas_new_30.csv",
    # "../embeddings/partially_annotated_batches_lung_atlas_new_50.csv",
    # "../embeddings/partially_annotated_batches_lung_atlas_new_70.csv",
    "../embeddings/mixing_at_edge_lung_atlas_new_30.csv",
    "../embeddings/mixing_at_edge_lung_atlas_new_50.csv",
    "../embeddings/mixing_at_edge_lung_atlas_new_70.csv",
    # "../embeddings/randomly_missing_lung_atlas_new_30.csv",
    # "../embeddings/randomly_missing_lung_atlas_new_50.csv",
    # "../embeddings/randomly_missing_lung_atlas_new_70.csv"
]

# Initialize the list of embedding keys to use
embedding_keys = ["X_scDREAMER", "X_ItClust"]

# Prepare a list to collect all results
all_results = []

# Loop through each file and calculate metrics
for file_path in file_paths:
    results = calculate_metrics_for_embeddings(file_path, adata, embedding_keys)
    all_results.extend(results)

# Now `all_results` contains metrics for all embedding files with identifying information
# Out:
# File: ../embeddings/cell_assign_lung_atlas_new.csv, Embedding: X_scDREAMER
# resolution: 0.1, nmi: 0.5053999955887378
# resolution: 0.2, nmi: 0.5106667553268743
# resolution: 0.3, nmi: 0.5425667734682197
# resolution: 0.4, nmi: 0.5504278621200288
# resolution: 0.5, nmi: 0.5507235407398867
# resolution: 0.6, nmi: 0.5537081746438708
# resolution: 0.7, nmi: 0.549824742949006
# resolution: 0.8, nmi: 0.5517777019302201
# resolution: 0.9, nmi: 0.5466119544922869
# resolution: 1.0, nmi: 0.5539978208560219
# resolution: 1.1, nmi: 0.5558701314827051
# resolution: 1.2, nmi: 0.5496044685462451
# resolution: 1.3, nmi: 0.5482495253739608
# resolution: 1.4, nmi: 0.5474652383636152
# resolution: 1.5, nmi: 0.536937086264264
# resolution: 1.6, nmi: 0.5419957157827673
# resolution: 1.7, nmi: 0.5421908040864585
# resolution: 1.8, nmi: 0.5420913353230497
# resolution: 1.9, nmi: 0.5385256151931542
# resolution: 2.0, nmi: 0.5292672976488744
# optimised clustering against cell_type
# optimal cluster resolution: 1.1
# optimal score: 0.5558701314827051
# Warning: cluster key cluster already exists in adata.obs and will be overwritten
# NMI...
# ARI...
# Silhouette score...
# Isolated labels F1...
# Compute neighbors on rep X_scDREAMER
# Isolated labels ASW...
# Graph connectivity...
# File: ../embeddings/cell_assign_lung_atlas_new.csv, Embedding: X_scDREAMER, Metric: 0, Score: NMI_cluster/label            0.555002
# ARI_cluster/label            0.407991
# ASW_label                    0.537260
# ASW_label/batch              0.896434
# PCR_batch                         NaN
# cell_cycle_conservation           NaN
# isolated_label_F1            0.263736
# isolated_label_silhouette    0.556097
# graph_conn                   0.913288
# kBET                              NaN
# iLISI                             NaN
# cLISI                             NaN
# hvg_overlap                       NaN
# trajectory                        NaN
# Name: 0, dtype: float64
# File: ../embeddings/cell_assign_lung_atlas_new.csv, Embedding: X_ItClust
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.2184797089198566
# resolution: 0.2, nmi: 0.2116269819426702
# resolution: 0.3, nmi: 0.20705207169383152
# resolution: 0.4, nmi: 0.21656400838449974
# resolution: 0.5, nmi: 0.20642714298233636
# resolution: 0.6, nmi: 0.2034262285279441
# resolution: 0.7, nmi: 0.20847912853999545
# resolution: 0.8, nmi: 0.2059601978894414
# resolution: 0.9, nmi: 0.20688919838661873
# resolution: 1.0, nmi: 0.20639153049136336
# resolution: 1.1, nmi: 0.20177390243008422
# resolution: 1.2, nmi: 0.20194132784621535
# resolution: 1.3, nmi: 0.20001828093180746
# resolution: 1.4, nmi: 0.19961394706730382
# resolution: 1.5, nmi: 0.20039030884611764
# resolution: 1.6, nmi: 0.19956365801850012
# resolution: 1.7, nmi: 0.19701266384350163
# resolution: 1.8, nmi: 0.19699634403795263
# resolution: 1.9, nmi: 0.19484553543043123
# resolution: 2.0, nmi: 0.19446463072638176
# optimised clustering against cell_type
# optimal cluster resolution: 0.1
# optimal score: 0.2184797089198566
# Warning: cluster key cluster already exists in adata.obs and will be overwritten
# NMI...
# ARI...
# Silhouette score...
# Isolated labels F1...
# Compute neighbors on rep X_ItClust
# Isolated labels ASW...
# Graph connectivity...
# File: ../embeddings/cell_assign_lung_atlas_new.csv, Embedding: X_ItClust, Metric: 0, Score: NMI_cluster/label            0.234763
# ARI_cluster/label            0.149931
# ASW_label                    0.274317
# ASW_label/batch              0.441021
# PCR_batch                         NaN
# cell_cycle_conservation           NaN
# isolated_label_F1            0.056319
# isolated_label_silhouette    0.236090
# graph_conn                   0.358664
# kBET                              NaN
# iLISI                             NaN
# cLISI                             NaN
# hvg_overlap                       NaN
# trajectory                        NaN
# Name: 0, dtype: float64
# File: ../embeddings/singleR_lung_atlas_new.csv, Embedding: X_scDREAMER
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.5390489118375598
# resolution: 0.2, nmi: 0.5315647882370018
# resolution: 0.3, nmi: 0.533516099835746
# resolution: 0.4, nmi: 0.5604127300948023
# resolution: 0.5, nmi: 0.5614151188553946
# resolution: 0.6, nmi: 0.5550605368045463
# resolution: 0.7, nmi: 0.5567243775684763
# resolution: 0.8, nmi: 0.5560110191927468
# resolution: 0.9, nmi: 0.5555775709975843
# resolution: 1.0, nmi: 0.5552466170327535
# resolution: 1.1, nmi: 0.551417411822372
# resolution: 1.2, nmi: 0.5504900646610829
# resolution: 1.3, nmi: 0.5439286617194369
# resolution: 1.4, nmi: 0.5439325996337212
# resolution: 1.5, nmi: 0.5445369812701902
# resolution: 1.6, nmi: 0.5342638921805059
# resolution: 1.7, nmi: 0.5421809865152192
# resolution: 1.8, nmi: 0.5356836158075667
# resolution: 1.9, nmi: 0.5397438317466787
# resolution: 2.0, nmi: 0.525563144696487
# optimised clustering against cell_type
# optimal cluster resolution: 0.5
# optimal score: 0.5614151188553946
# Warning: cluster key cluster already exists in adata.obs and will be overwritten
# NMI...
# ARI...
# Silhouette score...
# Isolated labels F1...
# Compute neighbors on rep X_scDREAMER
# Isolated labels ASW...
# Graph connectivity...
# File: ../embeddings/singleR_lung_atlas_new.csv, Embedding: X_scDREAMER, Metric: 0, Score: NMI_cluster/label            0.558690
# ARI_cluster/label            0.477094
# ASW_label                    0.534265
# ASW_label/batch              0.890947
# PCR_batch                         NaN
# cell_cycle_conservation           NaN
# isolated_label_F1            0.062278
# isolated_label_silhouette    0.458923
# graph_conn                   0.911538
# kBET                              NaN
# iLISI                             NaN
# cLISI                             NaN
# hvg_overlap                       NaN
# trajectory                        NaN
# Name: 0, dtype: float64
# File: ../embeddings/singleR_lung_atlas_new.csv, Embedding: X_ItClust
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.5077145612470751
# resolution: 0.2, nmi: 0.48538846846610995
# resolution: 0.3, nmi: 0.4815179026035257
# resolution: 0.4, nmi: 0.46904695738608454
# resolution: 0.5, nmi: 0.45896117090572336
# resolution: 0.6, nmi: 0.45637240710632637
# resolution: 0.7, nmi: 0.4496624278958988
# resolution: 0.8, nmi: 0.44287107558682026
# resolution: 0.9, nmi: 0.44248080181758753
# resolution: 1.0, nmi: 0.43523680202261716
# resolution: 1.1, nmi: 0.4348539943993946
# resolution: 1.2, nmi: 0.432593618351665
# resolution: 1.3, nmi: 0.42823322856494106
# resolution: 1.4, nmi: 0.4217672761682916
# resolution: 1.5, nmi: 0.4215473171980485
# resolution: 1.6, nmi: 0.4187960317822153
# resolution: 1.7, nmi: 0.41597211930912154
# resolution: 1.8, nmi: 0.41467694984049885
# resolution: 1.9, nmi: 0.41633377586739156
# resolution: 2.0, nmi: 0.41207962481363103
# optimised clustering against cell_type
# optimal cluster resolution: 0.1
# optimal score: 0.5077145612470751
# Warning: cluster key cluster already exists in adata.obs and will be overwritten
# NMI...
# ARI...
# Silhouette score...
# Isolated labels F1...
# Compute neighbors on rep X_ItClust
# Isolated labels ASW...
# Graph connectivity...
# File: ../embeddings/singleR_lung_atlas_new.csv, Embedding: X_ItClust, Metric: 0, Score: NMI_cluster/label            0.494016
# ARI_cluster/label            0.361183
# ASW_label                    0.456278
# ASW_label/batch              0.447460
# PCR_batch                         NaN
# cell_cycle_conservation           NaN
# isolated_label_F1            0.115163
# isolated_label_silhouette    0.180778
# graph_conn                   0.668959
# kBET                              NaN
# iLISI                             NaN
# cLISI                             NaN
# hvg_overlap                       NaN
# trajectory                        NaN
# Name: 0, dtype: float64
# File: ../embeddings/mixing_at_edge_lung_atlas_new_30.csv, Embedding: X_scDREAMER
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.7700809380752478
# resolution: 0.2, nmi: 0.7671834958707486
# resolution: 0.3, nmi: 0.7707374354207657
# resolution: 0.4, nmi: 0.7690756819840259
# resolution: 0.5, nmi: 0.7549516431975566
# resolution: 0.6, nmi: 0.7553352951835703
# resolution: 0.7, nmi: 0.7573526215181355
# resolution: 0.8, nmi: 0.7577631371898358
# resolution: 0.9, nmi: 0.7607552215167573
# resolution: 1.0, nmi: 0.7587588182517837
# resolution: 1.1, nmi: 0.7589541573814071
# resolution: 1.2, nmi: 0.7589311778676187
# resolution: 1.3, nmi: 0.7580590029235644
# resolution: 1.4, nmi: 0.7545194784384023
# resolution: 1.5, nmi: 0.7446096204366678
# resolution: 1.6, nmi: 0.7357749027136999
# resolution: 1.7, nmi: 0.7167035112805671
# resolution: 1.8, nmi: 0.7328680820336535
# resolution: 1.9, nmi: 0.7151780948701693
# resolution: 2.0, nmi: 0.7079763178907514
# optimised clustering against cell_type
# optimal cluster resolution: 0.3
# optimal score: 0.7707374354207657
# Warning: cluster key cluster already exists in adata.obs and will be overwritten
# NMI...
# ARI...
# Silhouette score...
# Isolated labels F1...
# Compute neighbors on rep X_scDREAMER
# Isolated labels ASW...
# Graph connectivity...
# File: ../embeddings/mixing_at_edge_lung_atlas_new_30.csv, Embedding: X_scDREAMER, Metric: 0, Score: NMI_cluster/label            0.773788
# ARI_cluster/label            0.694392
# ASW_label                    0.611472
# ASW_label/batch              0.858238
# PCR_batch                         NaN
# cell_cycle_conservation           NaN
# isolated_label_F1            0.830769
# isolated_label_silhouette    0.682456
# graph_conn                   0.957119
# kBET                              NaN
# iLISI                             NaN
# cLISI                             NaN
# hvg_overlap                       NaN
# trajectory                        NaN
# Name: 0, dtype: float64
# File: ../embeddings/mixing_at_edge_lung_atlas_new_30.csv, Embedding: X_ItClust
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.7609005653904254
# resolution: 0.2, nmi: 0.7230025999205427
# resolution: 0.3, nmi: 0.7114608397407018
# resolution: 0.4, nmi: 0.6893255107102771
# resolution: 0.5, nmi: 0.6761238117128106
# resolution: 0.6, nmi: 0.6635205682578644
# resolution: 0.7, nmi: 0.6586076922823405
# resolution: 0.8, nmi: 0.6443467083103289
# resolution: 0.9, nmi: 0.6459872135400925
# resolution: 1.0, nmi: 0.6343154536169254
# resolution: 1.1, nmi: 0.6370562581787375
# resolution: 1.2, nmi: 0.6240662056256363
# resolution: 1.3, nmi: 0.6210464467556466
# resolution: 1.4, nmi: 0.623055993296792
# resolution: 1.5, nmi: 0.6186524965648704
# resolution: 1.6, nmi: 0.6140410459845258
# resolution: 1.7, nmi: 0.6072598426049278
# resolution: 1.8, nmi: 0.6043638753635556
# resolution: 1.9, nmi: 0.6015778262351085
# resolution: 2.0, nmi: 0.5990587854820236
# optimised clustering against cell_type
# optimal cluster resolution: 0.1
# optimal score: 0.7609005653904254
# Warning: cluster key cluster already exists in adata.obs and will be overwritten
# NMI...
# ARI...
# Silhouette score...
# Isolated labels F1...
# Compute neighbors on rep X_ItClust
# Isolated labels ASW...
# Graph connectivity...
# File: ../embeddings/mixing_at_edge_lung_atlas_new_30.csv, Embedding: X_ItClust, Metric: 0, Score: NMI_cluster/label            0.759931
# ARI_cluster/label            0.697934
# ASW_label                    0.766062
# ASW_label/batch              0.494011
# PCR_batch                         NaN
# cell_cycle_conservation           NaN
# isolated_label_F1            0.590308
# isolated_label_silhouette    0.371213
# graph_conn                   0.819621
# kBET                              NaN
# iLISI                             NaN
# cLISI                             NaN
# hvg_overlap                       NaN
# trajectory                        NaN
# Name: 0, dtype: float64
# File: ../embeddings/mixing_at_edge_lung_atlas_new_50.csv, Embedding: X_scDREAMER
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.7929960819617102
# resolution: 0.2, nmi: 0.7960768933504262
# resolution: 0.3, nmi: 0.8044249980774523
# resolution: 0.4, nmi: 0.7968686136996675
# resolution: 0.5, nmi: 0.7815776231083891
# resolution: 0.6, nmi: 0.7867881927667072
# resolution: 0.7, nmi: 0.7810077909625861
# resolution: 0.8, nmi: 0.7843027785378929
# resolution: 0.9, nmi: 0.7847988183567324
# resolution: 1.0, nmi: 0.7829529891764516
# resolution: 1.1, nmi: 0.7845819907745386
# resolution: 1.2, nmi: 0.773987940877957
# resolution: 1.3, nmi: 0.7699697110167386
# resolution: 1.4, nmi: 0.7608552192031754
# resolution: 1.5, nmi: 0.7657494646554368
# resolution: 1.6, nmi: 0.7445934208950664
# resolution: 1.7, nmi: 0.7429063386600505
# resolution: 1.8, nmi: 0.7422031356942055
# resolution: 1.9, nmi: 0.7347747483014752
# resolution: 2.0, nmi: 0.723751421451602
# optimised clustering against cell_type
# optimal cluster resolution: 0.3
# optimal score: 0.8044249980774523
# Warning: cluster key cluster already exists in adata.obs and will be overwritten
# NMI...
# ARI...
# Silhouette score...
# Isolated labels F1...
# Compute neighbors on rep X_scDREAMER
# Isolated labels ASW...
# Graph connectivity...
# File: ../embeddings/mixing_at_edge_lung_atlas_new_50.csv, Embedding: X_scDREAMER, Metric: 0, Score: NMI_cluster/label            0.804397
# ARI_cluster/label            0.765734
# ASW_label                    0.619710
# ASW_label/batch              0.859983
# PCR_batch                         NaN
# cell_cycle_conservation           NaN
# isolated_label_F1            0.864600
# isolated_label_silhouette    0.687002
# graph_conn                   0.955868
# kBET                              NaN
# iLISI                             NaN
# cLISI                             NaN
# hvg_overlap                       NaN
# trajectory                        NaN
# Name: 0, dtype: float64
# File: ../embeddings/mixing_at_edge_lung_atlas_new_50.csv, Embedding: X_ItClust
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.7847291043544664
# resolution: 0.2, nmi: 0.7662336076451889
# resolution: 0.3, nmi: 0.755907895713417
# resolution: 0.4, nmi: 0.7449864915002212
# resolution: 0.5, nmi: 0.7360270808261962
# resolution: 0.6, nmi: 0.7206105463680564
# resolution: 0.7, nmi: 0.7015273426177613
# resolution: 0.8, nmi: 0.6936848936921903
# resolution: 0.9, nmi: 0.6993055311950552
# resolution: 1.0, nmi: 0.6899679690909301
# resolution: 1.1, nmi: 0.6734326189887294
# resolution: 1.2, nmi: 0.6829073026297847
# resolution: 1.3, nmi: 0.6746375250449497
# resolution: 1.4, nmi: 0.6702039096241427
# resolution: 1.5, nmi: 0.6634919162377254
# resolution: 1.6, nmi: 0.6651816755207826
# resolution: 1.7, nmi: 0.6576758318051334
# resolution: 1.8, nmi: 0.6532435362870506
# resolution: 1.9, nmi: 0.6503206319275339
# resolution: 2.0, nmi: 0.6517005392196227
# optimised clustering against cell_type
# optimal cluster resolution: 0.1
# optimal score: 0.7847291043544664
# Warning: cluster key cluster already exists in adata.obs and will be overwritten
# NMI...
# ARI...
# Silhouette score...
# Isolated labels F1...
# Compute neighbors on rep X_ItClust
# Isolated labels ASW...
# Graph connectivity...
# File: ../embeddings/mixing_at_edge_lung_atlas_new_50.csv, Embedding: X_ItClust, Metric: 0, Score: NMI_cluster/label            0.784301
# ARI_cluster/label            0.729339
# ASW_label                    0.789419
# ASW_label/batch              0.487244
# PCR_batch                         NaN
# cell_cycle_conservation           NaN
# isolated_label_F1            0.731006
# isolated_label_silhouette    0.482776
# graph_conn                   0.868669
# kBET                              NaN
# iLISI                             NaN
# cLISI                             NaN
# hvg_overlap                       NaN
# trajectory                        NaN
# Name: 0, dtype: float64
# File: ../embeddings/mixing_at_edge_lung_atlas_new_70.csv, Embedding: X_scDREAMER
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.8227400416434546
# resolution: 0.2, nmi: 0.8433701745515918
# resolution: 0.3, nmi: 0.8473332120852187
# resolution: 0.4, nmi: 0.84831770141943
# resolution: 0.5, nmi: 0.8277493724382337
# resolution: 0.6, nmi: 0.8300723042031384
# resolution: 0.7, nmi: 0.8275642183486712
# resolution: 0.8, nmi: 0.82565261349739
# resolution: 0.9, nmi: 0.8275908385407056
# resolution: 1.0, nmi: 0.8098700617655596
# resolution: 1.1, nmi: 0.807102548732692
# resolution: 1.2, nmi: 0.8084916807939797
# resolution: 1.3, nmi: 0.8054805163819773
# resolution: 1.4, nmi: 0.8041946747203186
# resolution: 1.5, nmi: 0.798223456835564
# resolution: 1.6, nmi: 0.7859235113816784
# resolution: 1.7, nmi: 0.7749741789605699
# resolution: 1.8, nmi: 0.7775336385893016
# resolution: 1.9, nmi: 0.7641489271210989
# resolution: 2.0, nmi: 0.7534174311354869
# optimised clustering against cell_type
# optimal cluster resolution: 0.4
# optimal score: 0.84831770141943
# Warning: cluster key cluster already exists in adata.obs and will be overwritten
# NMI...
# ARI...
# Silhouette score...
# Isolated labels F1...
# Compute neighbors on rep X_scDREAMER
# Isolated labels ASW...
# Graph connectivity...
# File: ../embeddings/mixing_at_edge_lung_atlas_new_70.csv, Embedding: X_scDREAMER, Metric: 0, Score: NMI_cluster/label            0.844506
# ARI_cluster/label            0.832400
# ASW_label                    0.633651
# ASW_label/batch              0.862013
# PCR_batch                         NaN
# cell_cycle_conservation           NaN
# isolated_label_F1            0.872154
# isolated_label_silhouette    0.701895
# graph_conn                   0.959316
# kBET                              NaN
# iLISI                             NaN
# cLISI                             NaN
# hvg_overlap                       NaN
# trajectory                        NaN
# Name: 0, dtype: float64
# File: ../embeddings/mixing_at_edge_lung_atlas_new_70.csv, Embedding: X_ItClust
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.8212191807736219
# resolution: 0.2, nmi: 0.7902246176192964
# resolution: 0.3, nmi: 0.7752733486607594
# resolution: 0.4, nmi: 0.7697009049884708
# resolution: 0.5, nmi: 0.7559159594295014
# resolution: 0.6, nmi: 0.7439451750215192
# resolution: 0.7, nmi: 0.7387418470577171
# resolution: 0.8, nmi: 0.7296049775612645
# resolution: 0.9, nmi: 0.7204399390917067
# resolution: 1.0, nmi: 0.7158124317949902
# resolution: 1.1, nmi: 0.7091038864529623
# resolution: 1.2, nmi: 0.6999225572316563
# resolution: 1.3, nmi: 0.6927330500140338
# resolution: 1.4, nmi: 0.6880292164854344
# resolution: 1.5, nmi: 0.680735071907892
# resolution: 1.6, nmi: 0.6755200709419149
# resolution: 1.7, nmi: 0.6743554333028178
# resolution: 1.8, nmi: 0.6692935114761387
# resolution: 1.9, nmi: 0.6644675243547717
# resolution: 2.0, nmi: 0.6633690184270714
# optimised clustering against cell_type
# optimal cluster resolution: 0.1
# optimal score: 0.8212191807736219
# Warning: cluster key cluster already exists in adata.obs and will be overwritten
# NMI...
# ARI...
# Silhouette score...
# Isolated labels F1...
# Compute neighbors on rep X_ItClust
# Isolated labels ASW...
# Graph connectivity...
# File: ../embeddings/mixing_at_edge_lung_atlas_new_70.csv, Embedding: X_ItClust, Metric: 0, Score: NMI_cluster/label            0.820326
# ARI_cluster/label            0.767903
# ASW_label                    0.818248
# ASW_label/batch              0.505308
# PCR_batch                         NaN
# cell_cycle_conservation           NaN
# isolated_label_F1            0.885246
# isolated_label_silhouette    0.743004
# graph_conn                   0.920028
# kBET                              NaN
# iLISI                             NaN
# cLISI                             NaN
# hvg_overlap                       NaN
# trajectory                        NaN
# Name: 0, dtype: float64

# %%
# Flatten the nested dictionaries and extract desired scores
results = []
for entry in all_results:
    file_path = entry['file_path']
    embedding_key = entry['embedding_key']
    score_series = entry['score']
    for metric, value in score_series.items():
        # Create an entry for each score
        results.append({
            'file_path': file_path,
            'embedding_key': embedding_key,
            'metric': metric,
            'score': value
        })

# Convert results list to DataFrame
results_df = pd.DataFrame(results)

# %%
results_df
# Out:
#                                              file_path embedding_key  \
# 0         ../embeddings/cell_assign_lung_atlas_new.csv   X_scDREAMER
# 1         ../embeddings/cell_assign_lung_atlas_new.csv   X_scDREAMER
# 2         ../embeddings/cell_assign_lung_atlas_new.csv   X_scDREAMER
# 3         ../embeddings/cell_assign_lung_atlas_new.csv   X_scDREAMER
# 4         ../embeddings/cell_assign_lung_atlas_new.csv   X_scDREAMER
# ..                                                 ...           ...
# 135  ../embeddings/mixing_at_edge_lung_atlas_new_70...     X_ItClust
# 136  ../embeddings/mixing_at_edge_lung_atlas_new_70...     X_ItClust
# 137  ../embeddings/mixing_at_edge_lung_atlas_new_70...     X_ItClust
# 138  ../embeddings/mixing_at_edge_lung_atlas_new_70...     X_ItClust
# 139  ../embeddings/mixing_at_edge_lung_atlas_new_70...     X_ItClust
#
#                 metric     score
# 0    NMI_cluster/label  0.555002
# 1    ARI_cluster/label  0.407991
# 2            ASW_label  0.537260
# 3      ASW_label/batch  0.896434
# 4            PCR_batch       NaN
# ..                 ...       ...
# 135               kBET       NaN
# 136              iLISI       NaN
# 137              cLISI       NaN
# 138        hvg_overlap       NaN
# 139         trajectory       NaN
#
# [140 rows x 4 columns]

# %%
results_df.to_csv('../metrics/lung_atlas_scib_metrics_new_2.csv', index=True)

# %% [markdown]
# ## Print the overall metrics for TPT

# %%
# Positive and true positive cells defined in iMAP
def positive_true_positive(adata, batch_key='batch', celltype_key='cell_type', use_raw=False,k1=20, k2=100, tp_thr=3., distance='cosine', embed='X_pca'):
    celltype_list = adata.obs[celltype_key]
    batch_list = adata.obs[batch_key]

    temp_c = adata.obs[celltype_key].value_counts()
    temp_b = pd.crosstab(adata.obs[celltype_key], adata.obs[batch_key])
    temp_b_prob = temp_b.divide(temp_b.sum(1), axis=0)
    
    if use_raw:
        if isinstance(adata.X, scipy.sparse.csr.csr_matrix):
            X = adata.X.todense()
        else:
            X = adata.X
    else:
        X = adata.obsm[embed]
    if distance == 'cosine':
        X = preprocessing.normalize(X, axis=1)

    t1 = KDTree(X)

    p_list = []
    tp_list = []

    for cell in range(len(X)):

        # Discriminate positive cells
        neig1 = min(k1, temp_c[celltype_list[cell]])
        NNs = t1.query(X[cell].reshape(1,-1), neig1+1, return_distance=False)[0, 1:]
        c_NN = celltype_list[NNs]
        true_rate = sum(c_NN == celltype_list[cell])/neig1
        if true_rate > 0.5:
            p_list.append(True)
        else:
            p_list.append(False)

        # Discriminate true positive cells
        if p_list[cell] == True:
            neig2 = min(k2, temp_c[celltype_list[cell]])
            NNs = t1.query(X[cell].reshape(1,-1), neig2, return_distance=False)[0]
            NNs_c = celltype_list[NNs]
            NNs_i = NNs_c == celltype_list[cell]
            NNs = NNs[NNs_i] # get local neighbors that are from the same cell type
            neig2 = len(NNs)
            NNs_b = batch_list[NNs]

            max_b = 0
            b_prob = temp_b_prob.loc[celltype_list[cell]]
            for b in set(batch_list):
                if b_prob[b] > 0 and b_prob[b] < 1:
                    p_b = sum(NNs_b == b)
                    stat_b = abs(p_b - neig2*b_prob[b]) / np.sqrt(neig2*b_prob[b]*(1-b_prob[b]))
                    max_b = max(max_b, stat_b)
            if max_b <= tp_thr:
                tp_list.append(True)
            else:
                tp_list.append(False)
        else:
            tp_list.append(False)

    pos_rate = sum(p_list)/len(p_list)
    truepos_rate = sum(tp_list)/len(tp_list)
    return pos_rate, truepos_rate

# %%
import pandas as pd
import scanpy as sc

def evaluate_embeddings(adata, file_paths, embedding_keys, batch_key='batch', celltype_key='cell_type', use_raw=False, k1=20, k2=100, tp_thr=3.0, distance='cosine'):
    results = []  # Initialize results as a list
    
    for file_path in file_paths:
        # Read the CSV file into a DataFrame
        combined_embeddings = pd.read_csv(file_path, index_col=0)
        
        # Ensure indices match
        combined_embeddings = combined_embeddings.loc[adata.obs_names]
        
        # Split the DataFrame into separate DataFrames for each embedding
        embeddings_dict = {key: combined_embeddings.filter(like=key) for key in embedding_keys}
        
        # Assign the embeddings back to adata.obsm
        for key, df in embeddings_dict.items():
            adata.obsm[key] = df.values
            
            # Evaluate embedding
            pos_rate, truepos_rate = positive_true_positive(
                adata,
                batch_key=batch_key,
                celltype_key=celltype_key,
                use_raw=use_raw,
                k1=k1,
                k2=k2,
                tp_thr=tp_thr,
                distance=distance,
                embed=key
            )
            
            # Store results with identifying information
            result_entry = {
                'file_path': file_path,
                'embedding_key': key,
                'pos_rate': pos_rate,
                'truepos_rate': truepos_rate
            }
            results.append(result_entry)
            
            # Print the file path, embedding key, and result
            print(f"File Path: {file_path}, Embedding Key: {key}, pos_rate: {pos_rate}, truepos_rate: {truepos_rate}")
    
    # Convert results list to DataFrame
    results_df = pd.DataFrame(results)
    
    return results_df

# %%
file_paths = [
    "../embeddings/full_annotated_supervised_lung_atlas_new.csv",
    # "../embeddings/cell_assign_lung_atlas_new.csv",
    "../embeddings/azimuth_lung_atlas_new.csv",
    # "../embeddings/singleR_lung_atlas_new.csv",
    "../embeddings/partially_annotated_batches_lung_atlas_new_30.csv",
    "../embeddings/partially_annotated_batches_lung_atlas_new_50.csv",
    "../embeddings/partially_annotated_batches_lung_atlas_new_70.csv",
    # "../embeddings/mixing_at_edge_lung_atlas_new_30.csv",
    # "../embeddings/mixing_at_edge_lung_atlas_new_50.csv",
    # "../embeddings/mixing_at_edge_lung_atlas_new_70.csv",
    "../embeddings/randomly_missing_lung_atlas_new_30.csv",
    "../embeddings/randomly_missing_lung_atlas_new_50.csv",
    "../embeddings/randomly_missing_lung_atlas_new_70.csv"
]

# Initialize the list of embedding keys to use
embedding_keys = ["X_scDREAMER", "X_ItClust"]


results_df = evaluate_embeddings(adata, file_paths, embedding_keys)

# Save the DataFrame to a CSV file
results_df.to_csv('./lung_atlas_true_positive_true_scores_new_1.csv', index=False)
# Out:
# File Path: ../embeddings/full_annotated_supervised_lung_atlas_new.csv, Embedding Key: X_scDREAMER, pos_rate: 0.9925143560295324, truepos_rate: 0.6274952146568226
# File Path: ../embeddings/full_annotated_supervised_lung_atlas_new.csv, Embedding Key: X_ItClust, pos_rate: 0.9037462400875034, truepos_rate: 0.4107533497402242
# File Path: ../embeddings/azimuth_lung_atlas_new.csv, Embedding Key: X_scDREAMER, pos_rate: 0.7526319387476074, truepos_rate: 0.30133989608969103
# File Path: ../embeddings/azimuth_lung_atlas_new.csv, Embedding Key: X_ItClust, pos_rate: 0.7603226688542521, truepos_rate: 0.21793820071096529
# File Path: ../embeddings/partially_annotated_batches_lung_atlas_new_30.csv, Embedding Key: X_scDREAMER, pos_rate: 0.6484140005468964, truepos_rate: 0.034078479628110475
# File Path: ../embeddings/partially_annotated_batches_lung_atlas_new_30.csv, Embedding Key: X_ItClust, pos_rate: 0.4077454197429587, truepos_rate: 0.033189773038009296
# File Path: ../embeddings/partially_annotated_batches_lung_atlas_new_50.csv, Embedding Key: X_scDREAMER, pos_rate: 0.7574172819250752, truepos_rate: 0.06863549357396773
# File Path: ../embeddings/partially_annotated_batches_lung_atlas_new_50.csv, Embedding Key: X_ItClust, pos_rate: 0.5819319114027892, truepos_rate: 0.03804347826086957
# File Path: ../embeddings/partially_annotated_batches_lung_atlas_new_70.csv, Embedding Key: X_scDREAMER, pos_rate: 0.8886724090784797, truepos_rate: 0.09686901832102816
# File Path: ../embeddings/partially_annotated_batches_lung_atlas_new_70.csv, Embedding Key: X_ItClust, pos_rate: 0.7530762920426579, truepos_rate: 0.05660377358490566
# File Path: ../embeddings/randomly_missing_lung_atlas_new_30.csv, Embedding Key: X_scDREAMER, pos_rate: 0.9373120043751709, truepos_rate: 0.5791290675417008
# File Path: ../embeddings/randomly_missing_lung_atlas_new_30.csv, Embedding Key: X_ItClust, pos_rate: 0.8292999726551818, truepos_rate: 0.44288351107465135
# File Path: ../embeddings/randomly_missing_lung_atlas_new_50.csv, Embedding Key: X_scDREAMER, pos_rate: 0.8832718074924801, truepos_rate: 0.5309338255400602
# File Path: ../embeddings/randomly_missing_lung_atlas_new_50.csv, Embedding Key: X_ItClust, pos_rate: 0.8046554552912223, truepos_rate: 0.4197429587093246
# File Path: ../embeddings/randomly_missing_lung_atlas_new_70.csv, Embedding Key: X_scDREAMER, pos_rate: 0.8062619633579436, truepos_rate: 0.4699207000273448
# File Path: ../embeddings/randomly_missing_lung_atlas_new_70.csv, Embedding Key: X_ItClust, pos_rate: 0.6525157232704403, truepos_rate: 0.3339827727645611

# %%
results_df
# Out:
#                                             file_path embedding_key  pos_rate  \
# 0   ../embeddings/full_annotated_supervised_lung_a...   X_scDREAMER  0.992514
# 1   ../embeddings/full_annotated_supervised_lung_a...     X_ItClust  0.903746
# 2            ../embeddings/azimuth_lung_atlas_new.csv   X_scDREAMER  0.752632
# 3            ../embeddings/azimuth_lung_atlas_new.csv     X_ItClust  0.760323
# 4   ../embeddings/partially_annotated_batches_lung...   X_scDREAMER  0.648414
# 5   ../embeddings/partially_annotated_batches_lung...     X_ItClust  0.407745
# 6   ../embeddings/partially_annotated_batches_lung...   X_scDREAMER  0.757417
# 7   ../embeddings/partially_annotated_batches_lung...     X_ItClust  0.581932
# 8   ../embeddings/partially_annotated_batches_lung...   X_scDREAMER  0.888672
# 9   ../embeddings/partially_annotated_batches_lung...     X_ItClust  0.753076
# 10  ../embeddings/randomly_missing_lung_atlas_new_...   X_scDREAMER  0.937312
# 11  ../embeddings/randomly_missing_lung_atlas_new_...     X_ItClust  0.829300
# 12  ../embeddings/randomly_missing_lung_atlas_new_...   X_scDREAMER  0.883272
# 13  ../embeddings/randomly_missing_lung_atlas_new_...     X_ItClust  0.804655
# 14  ../embeddings/randomly_missing_lung_atlas_new_...   X_scDREAMER  0.806262
# 15  ../embeddings/randomly_missing_lung_atlas_new_...     X_ItClust  0.652516
#
#     truepos_rate
# 0       0.627495
# 1       0.410753
# 2       0.301340
# 3       0.217938
# 4       0.034078
# 5       0.033190
# 6       0.068635
# 7       0.038043
# 8       0.096869
# 9       0.056604
# 10      0.579129
# 11      0.442884
# 12      0.530934
# 13      0.419743
# 14      0.469921
# 15      0.333983

# %% [markdown]
# ## Print the overall metrics for kBET

# %%
import pandas as pd
import scanpy as sc
import numpy as np
import scib  

import scipy.sparse as sp
# teach all csr_matrix objects that `.A` means “dense array”
sp.csr_matrix.A = property(lambda self: self.toarray())

def evaluate_embeddings(adata, file_paths, embedding_keys, batch_key='batch', celltype_key='cell_type'):
    results = []  # Initialize results as a list

    for file_path in file_paths:
        # Read the CSV file into a DataFrame
        combined_embeddings = pd.read_csv(file_path, index_col=0)

        # Ensure indices match
        combined_embeddings = combined_embeddings.loc[adata.obs_names]

        # Split the DataFrame into separate DataFrames for each embedding
        embeddings_dict = {key: combined_embeddings.filter(like=key) for key in embedding_keys}

        # Assign the embeddings back to adata.obsm
        for key, df in embeddings_dict.items():
            adata.obsm[key] = df.values

            # Calculate kBET score
            kbet_score = scib.metrics.kBET(
                adata,
                batch_key=batch_key,
                label_key=celltype_key,
                type_=None,
                embed=key,
                scaled=True,
                verbose=False,
            )

            # Store results with identifying information
            result_entry = {
                'file_path': file_path,
                'embedding_key': key,
                'kbet_score': kbet_score
            }
            results.append(result_entry)

            # Print the file path, embedding key, and result
            print(f"File Path: {file_path}, Embedding Key: {key}, kBET Score: {kbet_score}")

    # Convert results list to DataFrame
    results_df = pd.DataFrame(results)

    return results_df

# %%
# Assuming adata is your Annotated Data object
import numpy as np
from scipy.sparse import csr_matrix

# Convert the sparse matrix to a dense numpy array
adata.X = adata.X.toarray() if isinstance(adata.X, csr_matrix) else adata.X

file_paths = [
    "../embeddings/randomly_wrong_lung_atlas_30.csv",
    "../embeddings/randomly_wrong_lung_atlas_50.csv",
    "../embeddings/randomly_wrong_lung_atlas_70.csv"
]

# Initialize the list of embedding keys to use
embedding_keys = ["X_scANVI", 'X_scgen', 'X_stacas', 'X_scDREAMER', 'X_itclust']


results_df = evaluate_embeddings(adata, file_paths, embedding_keys)

# Save the DataFrame to a CSV file
results_df.to_csv('./raw_results/lung_atlas_kbet_scores_randomly_wrong.csv', index=False)
# Out:
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# File Path: ../embeddings/randomly_wrong_lung_atlas_30.csv, Embedding Key: X_scANVI, kBET Score: 0.5122940332690289
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# File Path: ../embeddings/randomly_wrong_lung_atlas_30.csv, Embedding Key: X_scgen, kBET Score: 0.570700959613698
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 9
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# File Path: ../embeddings/randomly_wrong_lung_atlas_30.csv, Embedding Key: X_stacas, kBET Score: 0.4651113592623367
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# File Path: ../embeddings/randomly_wrong_lung_atlas_30.csv, Embedding Key: X_scDREAMER, kBET Score: 0.75413765110829
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 9
# Adding diffusion to step 10
# Adding diffusion to step 11
# Adding diffusion to step 12
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 9
# Adding diffusion to step 10
# Adding diffusion to step 11
# Adding diffusion to step 12
# Adding diffusion to step 13
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 9
# File Path: ../embeddings/randomly_wrong_lung_atlas_30.csv, Embedding Key: X_itclust, kBET Score: 0.6098192764831095
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# File Path: ../embeddings/randomly_wrong_lung_atlas_50.csv, Embedding Key: X_scANVI, kBET Score: 0.5343850133263952
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# File Path: ../embeddings/randomly_wrong_lung_atlas_50.csv, Embedding Key: X_scgen, kBET Score: 0.517720809995792
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 9
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# File Path: ../embeddings/randomly_wrong_lung_atlas_50.csv, Embedding Key: X_stacas, kBET Score: 0.46586212407089267
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# File Path: ../embeddings/randomly_wrong_lung_atlas_50.csv, Embedding Key: X_scDREAMER, kBET Score: 0.753896983907999
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 9
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 9
# Adding diffusion to step 10
# Adding diffusion to step 11
# Adding diffusion to step 12
# File Path: ../embeddings/randomly_wrong_lung_atlas_50.csv, Embedding Key: X_itclust, kBET Score: 0.11882668955358844
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 4
# File Path: ../embeddings/randomly_wrong_lung_atlas_70.csv, Embedding Key: X_scANVI, kBET Score: 0.5633971496045302
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# File Path: ../embeddings/randomly_wrong_lung_atlas_70.csv, Embedding Key: X_scgen, kBET Score: 0.4839234621224323
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 4
# File Path: ../embeddings/randomly_wrong_lung_atlas_70.csv, Embedding Key: X_stacas, kBET Score: 0.45367301037351504
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# File Path: ../embeddings/randomly_wrong_lung_atlas_70.csv, Embedding Key: X_scDREAMER, kBET Score: 0.6727252254956408
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 4
# Adding diffusion to step 5
# Adding diffusion to step 6
# Adding diffusion to step 7
# Adding diffusion to step 8
# Adding diffusion to step 9
# Adding diffusion to step 10
# Adding diffusion to step 11
# Adding diffusion to step 12
# Adding diffusion to step 13
# Adding diffusion to step 14
# File Path: ../embeddings/randomly_wrong_lung_atlas_70.csv, Embedding Key: X_itclust, kBET Score: 0.06259080215877122

# %% [markdown]
# ## Print the overall metrics for LISI

# %%
# LISI
def calculate_LISI(adata, labels=None, total_cells=None, batch_key='batch', celltype_key='celltype', embed = 'X_pca'):
    if celltype_key is None:
        # Calculate bLISI
        lisi_b = 0
        lisi_c = lisi_f1 = np.nan
        if adata.shape[0] < 90:
            perplexity = int(adata.shape[0]/6)
        else:
            perplexity = 30
        lisi_res = lisi(adata.obsm[embed], adata.obs, batch_key, perplexity=perplexity)
        lisi_b = (np.mean(lisi_res)[batch_key]-1.)/(len(set(adata.obs[batch_key]))-1.)
    else:
        # Calculate 1-cLISI
        lisi_res = lisi(adata.obsm[embed], adata.obs, celltype_key)
        lisi_c = 1 - (np.mean(lisi_res)-1.)/(len(set(adata.obs[celltype_key]))-1.)

        # Calculate bLISI
        lisi_b = 0
        for label in labels:
            adata_sub = adata[adata.obs[celltype_key] == label]
            if adata_sub.shape[0] < 90:
                perplexity = int(adata_sub.shape[0]/6)
            else:
                perplexity = 30
            lisi_res = lisi(adata_sub.obsm[embed], adata_sub.obs, batch_key, perplexity=perplexity)
            lisi_batch = (np.mean(lisi_res)-1.)/(len(set(adata_sub.obs[batch_key]))-1.)
            lisi_b += lisi_batch*adata_sub.shape[0]
        lisi_b /= total_cells
        lisi_c = lisi_c.item()
        lisi_b = lisi_b.item()  # This will print only the value without the data type

        # Calcualte F1 score
        lisi_f1 = (2*lisi_c*lisi_b)/(lisi_c + lisi_b)
    
    return lisi_c, lisi_b, lisi_f1

# %%
def evaluate_embeddings(adata, file_paths, embedding_keys, batch_key='batch', celltype_key='cell_type'):
    results = []  # Initialize results as a list
    
    for file_path in file_paths:
        # Read the CSV file into a DataFrame
        combined_embeddings = pd.read_csv(file_path, index_col=0)
        
        # Ensure indices match
        combined_embeddings = combined_embeddings.loc[adata.obs_names]
        
        # Split the DataFrame into separate DataFrames for each embedding
        embeddings_dict = {key: combined_embeddings.filter(like=key) for key in embedding_keys}
        
        # Assign the embeddings back to adata.obsm
        for key, df in embeddings_dict.items():
            adata.obsm[key] = df.values
            
            # Evaluate embedding
            lisi_c, lisi_b, lisi_f1 = calculate_LISI(
                adata, labels=adata.obs[celltype_key].unique(), total_cells=adata.shape[0], batch_key=batch_key, celltype_key=celltype_key, embed=key
            )
            
            # Store results with identifying information
            result_entry = {
                'file_path': file_path,
                'embedding_key': key,
                'lisi_c': lisi_c,
                'lisi_b': lisi_b,
                'lisi_f1': lisi_f1
            }
            results.append(result_entry)
            
            # Print the file path, embedding key, and result
            print(f"File Path: {file_path}, Embedding Key: {key}, LISI_c: {lisi_c}, LISI_b: {lisi_b}, LISI_f1: {lisi_f1}")
    
    # Convert results list to DataFrame
    results_df = pd.DataFrame(results)
    
    return results_df

# %%
file_paths = [
    "../embeddings/full_annotated_supervised_lung_atlas_new.csv",
    "../embeddings/cell_assign_lung_atlas_new.csv",
    "../embeddings/azimuth_lung_atlas_new.csv",
    "../embeddings/singleR_lung_atlas_new.csv",
    "../embeddings/partially_annotated_batches_lung_atlas_new_30.csv",
    "../embeddings/partially_annotated_batches_lung_atlas_new_50.csv",
    "../embeddings/partially_annotated_batches_lung_atlas_new_70.csv",
    "../embeddings/mixing_at_edge_lung_atlas_new_30.csv",
    "../embeddings/mixing_at_edge_lung_atlas_new_50.csv",
    "../embeddings/mixing_at_edge_lung_atlas_new_70.csv",
    "../embeddings/randomly_missing_lung_atlas_new_30.csv",
    "../embeddings/randomly_missing_lung_atlas_new_50.csv",
    "../embeddings/randomly_missing_lung_atlas_new_70.csv"
]

# Initialize the list of embedding keys to use
embedding_keys = ["X_scDREAMER", "X_ItClust"]

results_df = evaluate_embeddings(adata, file_paths, embedding_keys)

# Save the DataFrame to a CSV file
results_df.to_csv('./lung_atlas_lisi_scores_new.csv', index=False)

# %% [markdown]
# # Combine the results for each settings

# %%
import pandas as pd

# 读入Excel文件
file_path = './lung_atlas_metrics.csv'  # 替换为你的文件路径
df = pd.read_csv(file_path)

# 处理数据，对每一个setting生成一个表
settings = df['type'].unique()
output_file = pd.ExcelWriter('./lung_atlas_metrics_grouped.xlsx')

# 创建一个Excel writer对象，利用openpyxl引擎
with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
    for setting in settings:
        setting_df = df[df['type'] == setting]

        # 创建透视表，将行设为method，列设为metric，score为值
        pivot_table = setting_df.pivot(index='method', columns='metric', values='score')

        # 写入新的Excel sheet中
        pivot_table.to_excel(writer, sheet_name=setting)
